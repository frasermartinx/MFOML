# %% [markdown]
# # Gaussian Processes Regression
#
# In this notebook, we will implement a Gaussian Processes Regression model from scratch and apply it to solve practical problems. The main objectives are:
#
# 1. Understanding how to fit a Gaussian Process Regression model.
#
# 2. Investigating how the kernel hyper-parameters can affect the model fitting.
#
# 3. Understanding how to select kernel hyper-parameters via *marginal loglikelihood optimisation*.

# %%
import torch
import numpy as np
import pandas as pd
from typing import Callable, Optional

import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Important in this tutorial due to numerical precision
torch.set_default_dtype(torch.float64)
# Out:
# C:\Users\frase\AppData\Local\Temp\ipykernel_109132\4141879632.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Toy Dataset
# ***

# %% [markdown]
# As a start, we will consider a synthetic dataset consisting of 3 data points of dimension 1, $X = \{x_1, x_2, x_3 \} = \{ -1, 0, 1 \}$, and the response variables $y = \{y_1, y_2, y_3\}$ are generated as follows:
# \begin{align*}
#   y_i &= f(x_i) = \frac{1}{1 + \exp(- x_i)} - 1 \;.
# \end{align*}

# %%
def f(x):
    """
    This function applies the sigmoid function and then subtracts 1.

    Args:
    x (torch.Tensor): Input tensor.

    Returns:
    torch.Tensor: Transformed tensor.
    """

    ###### TODO ######
    return (1/(1+torch.exp(-x))-1)

# observed data
toy_X = torch.tensor([-1., 0., 1.])

toy_y = f(toy_X)

# Plot observed data
plot_x = torch.linspace(-5., 5., 100)
plt.plot(plot_x.numpy(), f(plot_x).numpy())  # Converting tensors to numpy arrays for plotting
plt.scatter(toy_X.numpy(), toy_y.numpy(), color="red", s=70)
plt.title("Toy data")
plt.grid()
plt.show()

# %% [markdown]
# Expected output:
# ```python
# toy_y: tensor([-0.7311, -0.5000, -0.2689])
# ```

# %% [markdown]
# ## Specifying a GP Prior
# ***

# %% [markdown]
# Our aim is to approximate the function $f$ by fitting a Gaussian Process. That is, we place a GP prior on $f$ and seek the posterior distribution of $f$ conditional on the observed data.
#
# We will use a **noisy observations** model $y_i = f(x_i) + \epsilon_i$, where $\epsilon_i \sim \mathcal{N}(0, \sigma^2)$ are i.i.d. Gaussian noise with variance $\sigma^2$. Recall the GP model with mean function $m$ and kernel (covariance) function $K$ is,
#
# $$
#   f(X) \sim \mathcal{N}(m(X), K(X, X)) \;,
# $$
#
# where $X = (x_1, \ldots, x_N)$. Choosing a **zero function** for $m$, the posterior distribution at $M$ new test points $X^* = (x_1^*, \ldots, x_M^*)$ is
#
# $$
# \begin{align*}
#   f^* | X, \mathbf{y}, X^*
#   &\sim \mathcal{N}( \tilde{m} ,\; \tilde{\Sigma} ) \;, \\
#   \tilde{m} &= K(X^*, X) [ K(X, X) + \sigma^2 I_n ]^{-1} \mathbf{y}, \\
#   \tilde{\Sigma} &= K(X^*, X^*) - K(X^*, X) [K(X, X) + \sigma^2 I_n]^{-1} K(X, X^*) ).
# \end{align*}
# $$
#
# Remarks:
#
# 1. **Zero prior mean:** The choice of $m \equiv 0$ is without loss of generality because we can always center the response variable by subtracting its empirical mean.
#
# 2. **Noisy observation model:** We could in principle use a noise-free observation model for this toy dataset. However, using the noisy model allows us to write the code in more generality, which will be helpful when we work with the real-life dataset in the second part of this notebook. Moreover, we will see later how to select the model hyper-parameters using a data-centric approach (i.e., log marginal likelihood maximisation). If the data are indeed generated from a noiseless process, then we should be able to recover the noise-free setting by selecting a very small $\sigma_2$.
#
# For the **kernel function**, we will use the **Squared Exponential** kernel, also known as the **Radial Basis Function** (RBF) kernel. It is one of the most widely used choice of kernel function. Recall from the lecture notes that it is defined as
#
# $$
# k(x, x') = \theta_1^2 \exp\left( - \frac{1}{2 \theta_2^2} \| x - x' \|_2^2 \right) \;,
# $$
#
# where $\theta_1, \theta_2 > 0$ are hyper-parameters that we need to specify. As we will see, the choice of these kernel hyper-parameters can have significant impact on the model quality. In practice, they are often chosen in a ''data-centric'' mannor, or by domain knowledge of the problem at hand.
#
# For now, we will set $\theta_1, \theta_2 = 1$.
#
# Also note that $d = 1$ in this example, so the squared $l_2$ norm reduces to $(x-x')^2$. But we are going to implement the multidimensional setting.

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Implement a RBF kernel by completing the code below.
#
# Your `RBF` class should
#
# 1. take as its input two tensors of **potentially different** shapes, e.g., x1.shape = $[n,d]$ and x2.shape = $[m,d]$.
#
# 2. output a kernel matrix with appropriate shape, e.g. if x1.shape = $[4,3]$ and x2.shape = $[10,3]$ then $k(x, y)$ is a $4 \times 10$ tensor, where $k(x, y)_{i, j} = k(x_i, y_j)$.
#
# 3. Your code should use vectorised operations for fast computation.

# %%
# Hint on how to compute ||x1-x2||^2 for x1 with shape (n, d) and x2 with shape (m, d): Use broadcasting! (GOOGLE IT!)
# Expand the tensors to have shape (n, m, d) using unsqueeze (not by repeating it and store the same data).
# You can now subtract them and compute the norm

# %%
class Kernel:
  """
  How the kernel classes should look like.
  ##################################
  the __call__ method allows you to call the class as if it were a function. Example:
  #the call method tells the class what to do if we call it directly
  #ie we want to make an instance of it and have it do something upon instanciating
  >>> ker = Kernel(params)
  >>> result = ker(x1,x2)
  """

  def __init__(self, params : dict):
    pass

  def __call__(self, x1, x2):
    raise NotImplementedError()
  

  # Static method means that it is a normal function, but it is inside the class (no self argument)
  # DO NOT CHANGE THIS METHOD
  @staticmethod
  def check_shapes(x1,x2):
    """
    Checks if the input tensors have the correct shape. If the tensor is 1D, it will be converted to 2D with shape (n,1).
    """
    if len(x1.shape) == 1:
      x1 = x1.unsqueeze(1)
    elif len(x1.shape) > 2:
      raise ValueError("Expected x to be a tensor of dimension 1 or 2, but got {}".format(len(x1.shape)))
    
    if len(x2.shape) == 1:
      x2 = x2.unsqueeze(1)
    elif len(x2.shape) > 2:
      raise ValueError("Expected y to be a tensor of dimension 1 or 2, but got {}".format(len(x2.shape)))
    
    if x1.shape[1] != x2.shape[1]:
      raise ValueError("Expected x and y to have the same number of columns, but got {} and {}".format(x1.shape[1], x2.shape[1]))
    
    return x1,x2


class RBF(Kernel):

    def __init__(self, params : dict):

        # Unpack params
        self.theta1 = params['theta1']
        self.theta2 = params['theta2']

    def set_params(self, params: dict):
        
        self.theta1 = params['theta1']
        self.theta2 = params['theta2']

    def __call__(self, x1, x2):
        """
        Radial Basis Function (RBF) kernel implementation in PyTorch.
        Given an input tensor x of size n and another input tensor y of size m,
        compute the n by m kernel matrix whose (i, j)-th entry is k(x1_i, x2_j).

        Args:
        x1 (torch.Tensor): Input tensor of shape (n, d) where d is the number of dimensions.
        Same dimensionality but could have different numbers since eg training data and predictive
        x2 (torch.Tensor): Input tensor of shape (m, d) where d is the number of dimensions.

        Returns:
        torch.Tensor: Kernel matrix of shape (n, m).
        """

        x1, x2 = self.check_shapes(x1, x2)
        # Calculate pairwise squared Euclidean distances
        diff = x1.unsqueeze(1) - x2.unsqueeze(0)  # Broadcasting to get pairwise differences
        #sum over last dimension which is of course dimension
        squared_diff_matrix = (diff ** 2).sum(dim=-1)

        ###### TODO ######
        # Compute the RBF kernel matrix
        k_mat = self.theta1 ** 2 * torch.exp(-1/(2 * self.theta2 ** 2) * squared_diff_matrix)

        return k_mat

# %%
# Testing the rbf kernel
rbf_params_testing = {'theta1': 1., 'theta2': 1.}

rbf_testing = RBF(rbf_params_testing)
rbf_testing(toy_X, toy_X)
# Out:
# tensor([[1.0000, 0.6065, 0.1353],
#         [0.6065, 1.0000, 0.6065],
#         [0.1353, 0.6065, 1.0000]])

# %% [markdown]
# Expected output:
# ```python
# tensor([[1.0000, 0.6065, 0.1353],
#         [0.6065, 1.0000, 0.6065],
#         [0.1353, 0.6065, 1.0000]])
# ```

# %% [markdown]
# ## Gaussian Processes Regression
# ***
#
# We now implement a GP where the prior mean is assumed to be the **zero function**. The same logic will follow if an arbitrary mean function was used, except that the posterior mean and covariance will take a different form.

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Implement a Gaussian Process model by completing the `predict` method below. Your code should
#
# 1. Compute the posterior mean 1d-tensor and covariance matrix for a given tensor of test points `x_star`.
#
# Try to use `torch.linalg.solve` to compute something like $X^{-1}y$ or $X^{-1}X^*$. Not sure but it might be faster (and if not you have learned a new way to do it :) )

# %%
class GP:
    
    def __init__(self, kernel: Callable):
        """
        Initialize the Gaussian Process (GP) with a specified kernel.

        Args:
        kernel (callable): The kernel function to use in the GP.
        """
        self.k = kernel

    def predict(self, x_star, X=None, y=None, size=1, sigma=0.):
        """
        Given observations (X, y) and test points x_star, fit a GP model
        and draw posterior samples for f(x_star) from the fitted model.

        Args:
        x_star (torch.Tensor): Test points at which predictions will be made.
        X (torch.Tensor): Observed features.
        y (torch.Tensor): Observed response variables.
        size (int): Number of posterior samples to draw.
        sigma (float): Noise level in observations.

        Returns:
        torch.Tensor: Posterior samples for f(x_star).
        """

        ###### TODO ######
        # Compute kernel matrices
        #same format as the one we just made
        k_xs_x   = self.k(x_star,X)       # m x n
        k_x_xs   = self.k(X,x_star)      # n x m
        k_xs_xs  = self.k(x_star,x_star)       # m x m
        k_x_x    = self.k(X,X)       # n x n
        cov_x_x  = k_x_x + sigma**2 * torch.eye(X.shape[0])        # n x n        # Hint: Add sigma^2 to the diagonal of k_x_x

        ###### TODO ######
        # Compute posterior mean and covariance
        posterior_mean = torch.linalg.matmul(k_xs_x ,torch.linalg.solve(cov_x_x,y))
        posterior_var = k_xs_xs - torch.matmul(k_xs_x,torch.linalg.solve(cov_x_x,k_x_xs))
        
        # -----------------------------------------------------------------------------------
        # Enforce symmetry and positive definiteness that may be lost due to numerical errors
        posterior_var = (posterior_var + posterior_var.T) / 2  # Enforce symmetry
        # Add a small amount of noise to the diagonal to make the covariance matrix positive definite
        posterior_var = posterior_var + 1e-6 * torch.eye(posterior_var.shape[0])
        # -----------------------------------------------------------------------------------
        
        self.posterior_mean = posterior_mean
        self.posterior_var = posterior_var

        # Draw samples from the posterior distribution
        y_star = torch.distributions.MultivariateNormal(posterior_mean, posterior_var).sample((size,))

        return y_star

# %%
# Instantiate GP model
gp_testing = GP(kernel=rbf_testing)

# Initialise test points
toy_xp = torch.linspace(-3., 3., 51)

# Kernel hyper-params
sigma = 0.

# Set seed for reproducibility
torch.manual_seed(123)

# Compute posterior samples
yp = gp_testing.predict(x_star=toy_xp, X=toy_X, y=toy_y, size=100, sigma=0.0)

print(yp.shape)
print(yp[0,:9])
# Out:
# torch.Size([100, 51])
# tensor([0.7945, 0.7716, 0.7394, 0.6978, 0.6462, 0.5836, 0.5101, 0.4201, 0.3164])

# %% [markdown]
# Expected output:
# ```python
# torch.Size([100, 51])
# tensor([0.7945, 0.7716, 0.7394, 0.6978, 0.6462, 0.5836, 0.5101, 0.4201, 0.3164])
# ```

# %% [markdown]
#  We now fit a GP model on our observations. For the hyper-parameters $\theta = (\theta_1, \theta_2)$ of the RBF kernel, we choose arbitrarily $\theta_1 = \theta_2 = 1$. We will discuss the effect of different values on the fitted result in the next section.

# %%
# Plot posterior draws and observations
fig = plt.figure()
plt.plot(toy_xp.numpy(), yp.T.numpy(), color="grey", alpha=0.2)
plt.scatter(toy_X, toy_y, color="red", s=70)
plt.title("Posterior samples")
plt.show()

# %% [markdown]
# ## Effect of Kernel Hyper-Parameters
# ***
#
# The choice of the kernel hyper-parameters can often have significant consequences on the fitted GP.

# %%
# ---------------------------------------------------------------------------------
# UTILS FUNCTIONS FOR PLOTTING DO NOT CHANGE - unless you know what you are doing
# Have a look at them to learn how to plot in python!!
# ---------------------------------------------------------------------------------

def plot_varying_theta(theta1_list : Optional = None, 
                       theta2_list : Optional = None, 
                       theta1_fixed : float = 1., 
                       theta2_fixed : float = 1.,):
    """
    Plot posterior draws from GPs fitted with different theta1 and
    fixed theta2.

    Args:
    theta1_list (list): List of theta1 values to use for the RBF kernel.
    theta2 (float): The fixed value of theta2 for the RBF kernel.
    toy_X (torch.Tensor): Observed features.
    toy_y (torch.Tensor): Observed response variables.
    toy_xp (torch.Tensor): Test points at which predictions will be made.
    """
    nrow = 2
    ncol = 3

    if theta1_list is None and theta2_list is None:
        raise ValueError("At least one of theta1_list and theta2_list must be specified.")

    if theta1_list is not None:

        print('=' * 80)
        print("Varying theta1 and fixing theta2 to {}".format(theta2_fixed))
        print('=' * 80)

        fig, axes = plt.subplots(nrows=nrow, ncols=ncol, figsize=(12, 8))

        for i, theta1 in enumerate(theta1_list):

            params = {'theta1': theta1, 'theta2': theta2_fixed}
            rbf = RBF(params)
            gp = GP(kernel=rbf)
            yp = gp.predict(x_star=toy_xp, X=toy_X, y=toy_y, size=100, sigma=0.1)

            yp = yp.detach().numpy()  # Convert to numpy for plotting
            axes[i // ncol][i % ncol].plot(toy_xp.numpy(), yp.T, color="grey", alpha=0.2)
            axes[i // ncol][i % ncol].scatter(toy_X.numpy(), toy_y.numpy(), color="red", s=70)
            axes[i // ncol][i % ncol].set_xlim(-3., 3.)
            axes[i // ncol][i % ncol].set_ylim(-20., 20.)
            axes[i // ncol][i % ncol].set_title(f"theta1 = {theta1}")

        plt.tight_layout()
        plt.show()

    # ---------------------------------------------------------------------------------
        
    if theta2_list is not None:

        print('=' * 80)
        print("Varying theta2 and fixing theta1 to {}".format(theta1_fixed))
        print('=' * 80)
        
        fig, axes = plt.subplots(nrows=nrow, ncols=ncol, figsize=(12, 8))

        for i, theta2 in enumerate(theta2_list):

            params = {'theta1': theta1_fixed, 'theta2': theta2}
            rbf = RBF(params)
            gp = GP(kernel=rbf)
            yp = gp.predict(x_star=toy_xp, X=toy_X, y=toy_y, size=100, sigma=0.1)

            yp = yp.detach().numpy()  # Convert to numpy for plotting
            axes[i // ncol][i % ncol].plot(toy_xp.numpy(), yp.T, color="grey", alpha=0.2)
            axes[i // ncol][i % ncol].scatter(toy_X.numpy(), toy_y.numpy(), color="red", s=70)
            axes[i // ncol][i % ncol].set_xlim(-3., 3.)
            axes[i // ncol][i % ncol].set_ylim(-10., 10.)
            axes[i // ncol][i % ncol].set_title(f"theta2 = {theta2}")

        plt.tight_layout()
        plt.show()


def interactive_plot1(theta1, theta2):
    """
    Plot posterior draws from GPs fitted with specified theta1 and theta2.

    Args:
    theta1 (float): Value of theta1 for the RBF kernel.
    theta2 (float): Value of theta2 for the RBF kernel.
    toy_X (torch.Tensor): Observed features.
    toy_y (torch.Tensor): Observed response variables.
    toy_xp (torch.Tensor): Test points at which predictions will be made.
    """

    params = {'theta1': theta1, 'theta2': theta2}
    rbf = RBF(params)
    gp = GP(kernel=rbf)
    yp = gp.predict(x_star=toy_xp, X=toy_X, y=toy_y, size=100, sigma=0.1)

    yp = yp.detach().numpy()  # Convert to numpy for plotting
    plt.figure(figsize=(8, 6))
    plt.plot(toy_xp.numpy(), yp.T, color="grey", alpha=0.2)
    plt.scatter(toy_X.numpy(), toy_y.numpy(), color="red", s=70)
    plt.xlim(-3., 3.)
    plt.ylim(-20., 20.)
    plt.title(f"theta1 = {round(theta1,4)}, theta2 = {round(theta2,4)}")
    plt.show()

# Assuming toy_X, toy_y, and toy_xp are predefined tensors
theta1_slider = widgets.FloatLogSlider(
    value=1.0, 
    base=10,
    min=np.log10(0.1),  # min value (log scale)
    max=np.log10(20),   # max value (log scale)
    step=0.1, 
    description='Theta1:')

theta2_slider = widgets.FloatLogSlider(
    value=1.0, 
    base=10,
    min=np.log10(0.1),  # min value (log scale)
    max=np.log10(20),   # max value (log scale)
    step=0.1, 
    description='Theta2:')

# %%
# Plotting
theta1_list = np.array([0.1, 0.5, 1., 5., 10., 50.])
theta2_list = np.array([0.1, 0.5, 1., 5., 10., 50.])

plot_varying_theta(theta1_list=theta1_list, theta2_list=theta2_list)
# Out:
# ================================================================================
# Varying theta1 and fixing theta2 to 1.0
# ================================================================================
# ================================================================================
# Varying theta2 and fixing theta1 to 1.0
# ================================================================================

# %%
# Interactive plot
widgets.interactive(interactive_plot1, theta1=theta1_slider, theta2=theta2_slider)
# Out:
# interactive(children=(FloatLogSlider(value=1.0, description='Theta1:', max=1.3010299956639813, min=-1.0), Floa…

# %% [markdown]
# #### Exercise 3
# Comment on how these two hyper-parameters affect the posterior samples.
#
# <details><summary>Hint</summary>
# <p>
#
# Provide mathematical interpretations by assuming $\sigma = 0$ (i.e., a **noise-free** model) and arguing how the posterior mean and covariance matrix change with $\theta_1$ and $\theta_2$.
#
# </p>
# </details>

# %% [markdown]
# ## Model Selection
# ***

# %% [markdown]
# One famous approach to optimise the hyper-parameters in a GP model is by maximising the so-called **marginal likelihood** (also known as **evidence**), $p(y | X)$.
#
# It is defined as the following integral of the likelihood multiplied by the prior:
#
# $$
#   p(y | X) = \int p(y | f, X) p(f | X) df \;.
# $$
#
# The term **marginal** refers to the marginalisation over the functions $f$. Under a GP model, the prior is Gaussian, $f | X \sim \mathcal{N}(0, K)$, so
#
# $$
#   \log p(f | X) = -\frac{1}{2} f^\top K(X, X)^{-1} f - \frac{1}{2} \log | K(X, X) | - \frac{n}{2} \log2 \pi \;.
# $$
#
# Under the noisy observation assumption, $y_i = f(x_i) + \epsilon$ where $\epsilon \sim \mathcal{N}(0, \sigma^2)$, so the likelihood is a factorised Gaussian $y | f, X \sim \mathcal{N}(f(X), \sigma^2 I_n)$.
#
# Using the fact that the product of Gaussians is still a Gaussian (see lecture notes), we conclude (**exercise**):
#
# $$
# \begin{align*}
#   \log p(y | X) = - \frac{1}{2} y^\top (K(X, X) + \sigma^2 I_n)^{-1} y - \frac{1}{2} \log | K(X, X) + \sigma^2 I_n | - \frac{n}{2} \log 2\pi \;.
# \end{align*}
# $$
#
# We call the above equation the **log marginal likelihood**.
# <!-- To emphasize its dependence on the hyper-parameters $\theta$ and $\sigma$, we also write $\log p(y | X, \theta, \sigma)$.  -->
#
# The three terms here have intuitive roles:
# - $- \frac{1}{2} y^\top (K(X, X) + \sigma^2 I_n)^{-1} y$ is the **data fit** and is the only term involving the observed targets $y$.
#
# - $\log | K(X, X) + \sigma^2 I_n |$ is the **complexity penalty** that depends only on the input $X$ and kernel fuction.
#
# - $\frac{n}{2} \log 2\pi$ is a **normalising constant** that does not depend on the hyper-parameters $\theta$ nor $\sigma$, so it can be ignored when performing optimisation.
#
# **DO NOT USE THIS NORMALISING CONSTANT IN THE EXERCISE (OR YOU WILL GET DIFFERENT VALUES)**

# %% [markdown]
# #### Exercise 4
# Implement the log marginal likelihood by completing the `marginal_loglik` method in the `GP` class defined in the previous section.
# - Your code should be numerically stable. You might find `torch.linalg.slogdet` useful.

# %%
# Not a vary nice way to add a method to a class but for now it works

class GP(GP):
    
    def __init__(self, kernel: callable):
        """
        Initialize the Gaussian Process (GP) with a specified kernel.

        Args:
        kernel (callable): The kernel function to use in the GP.
        """
        self.k = kernel

    def marginal_loglik(self, X, y, sigma=0.):
        """
        Compute the marginal log likelihood of a GP model given observations.

        Args:
        X (torch.Tensor): Observed features.
        y (torch.Tensor): Observed response variables.
        theta (list): Kernel hyperparameters.
        sigma (float): Noise level in observations.

        Returns:
        float: Marginal log likelihood of the GP model.
        """

        ###### TODO ######
        # Compute kernel matrix
        k_x_x = self.k(X,X)  # n x n
        cov_x_x = k_x_x + sigma**2 * torch.eye(k_x_x.shape[0])  # n x n

        ###### TODO ######
        # Compute complexity penaly and datafit
        data_fit = -0.5 * torch.matmul(y.T,torch.linalg.solve(cov_x_x,y))
        print(torch.linalg.slogdet(cov_x_x))
        _,log_det = torch.linalg.slogdet(cov_x_x)
        penalty = -0.5 * log_det
        log_lik = data_fit + penalty 
        
        return log_lik

# %%
# Testing
gp_testing = GP(kernel=rbf_testing)

gp_testing.marginal_loglik(X=toy_X, y=toy_y, sigma=sigma)
# Out:
# torch.return_types.linalg_slogdet(
# sign=tensor(1.),
# logabsdet=tensor(-1.0628))
# C:\Users\frase\AppData\Local\Temp\ipykernel_109132\1780508035.py:35: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3618.)
#   data_fit = -0.5 * torch.matmul(y.T,torch.linalg.solve(cov_x_x,y))
# tensor(0.2478)

# %% [markdown]
# Expected output:
# ```python
# tensor(0.2478)
#
# ```

# %% [markdown]
# To find the best hyper-parameters, we seek the **partial derivatives** of the marginal loglikelihood with respect to $\theta$ and $\sigma$, i.e., $\frac{\partial}{\partial \theta_j} \log p(y | X) $ and $\frac{\partial}{\partial \sigma} \log p(y | X) $. This can be done by either manually computing these derivatives, or using **auto-differentiation**.
#
# In this notebook, we will use [**auto-differentiation**](https://en.wikipedia.org/wiki/Automatic_differentiation) and the optimisation algorithm Adam to perform the hyper-parameter search.
#
# Since our aim is to **maximise** the log marginal likelihood, we will set the objective function to be the **negative log marginal likelihood**.

# %% [markdown]
# #### Excercise 5
#
# Implement the optimizisation loop. You might want to google how torch.optim class works.

# %%
def optim_hyperparams(gp, init_params, data_X, data_y, maxiter=60, learning_rate=0.02):
    """
    Optimize the hyperparameters of a Gaussian Process model to maximize the 
    log marginal likelihood. This function uses gradient descent with the Adam 
    optimizer to iteratively adjust the hyperparameters.

    Args:
    gp (GP): An instance of the Gaussian Process model.
    init_params (dict): A dictionary containing initial values of hyperparameters.
                        The keys should include 'sigma' and other parameters required by the kernel.
    data_X (torch.Tensor): Input features as a torch.Tensor.
    data_y (torch.Tensor): Output/target values as a torch.Tensor.
    maxiter (int, optional): The number of iterations for the optimization process. Default is 60.
    learning_rate (float, optional): The learning rate for the Adam optimizer. Default is 0.02.

    Returns:
    dict: A dictionary containing:
          - 'optimized_params': Hyperparameters that resulted in the maximum log likelihood.
          - 'max_log_likelihood': The maximum log likelihood value achieved during optimization.
          - 'log_likelihood_history': A list of log likelihood values over iterations.
          - 'params_history': A dictionary mapping each hyperparameter to a list of its values over iterations.
    """

    assert isinstance(init_params, dict), "init_params must be a dictionary."
    assert 'sigma' in init_params.keys(), 'sigma must be in init_params'

    # Flatten all parameters into a single tensor
    params_tensor = torch.tensor([init_params[key] for key in sorted(init_params.keys())],
                                 dtype=torch.float64, requires_grad=True)


    log_likelihood_history = []
    params_history = []

    # Use PyTorch optimizer
    optimizer = torch.optim.Adam([params_tensor], lr=learning_rate)

    for _ in range(maxiter):

        ###### TODO ######
        # Set gradients to zero
        optimizer.zero_grad()

        # Update kernel parameters
        updated_params = {key: val for key, val in zip(sorted(init_params.keys()), params_tensor)}
        gp.k.set_params(updated_params)

        ###### TODO #####   
        # Compute NEGATIVE log likelihood
        neg_log_likelihood = -gp.marginal_loglik(data_X,data_y,sigma = updated_params["sigma"])  # Hint: Use the marginal_loglik method of the GP class and sigma here is updated_params['sigma']

        log_likelihood_history.append(-neg_log_likelihood.item())
        params_history.append(params_tensor.clone().detach())  # Store a copy of the current parameters

        ###### TODO ######
        # Perform backpropagation
        neg_log_likelihood.backward()

        ###### TODO ######
        # Update parameters using step method
        optimizer.step()

    # Extract the optimized parameters and the corresponding log likelihood if they happen before maxiter
    max_log_likelihood_idx = torch.argmax(torch.tensor(log_likelihood_history)).item()  
    max_log_likelihood = max(log_likelihood_history)  
    optimal_params_tensor = params_history[max_log_likelihood_idx]

    params_history = torch.stack(params_history).transpose(0, 1)
    params_history = {key: val for key, val in zip(sorted(init_params.keys()), params_history)}

    # Return the optimized parameters
    optimized_params = {key: val.item() for key, val in zip(sorted(init_params.keys()), optimal_params_tensor)}


    return {'optimized_params': optimized_params, 'max_log_likelihood': max_log_likelihood,
            'log_likelihood_history': log_likelihood_history, 'params_history': params_history}


def plot_likelihood_history(loss_history):
    """
    Plot the history of the log marginal likelihood.

    Args:
    loss_history (list): List of negative log marginal likelihood values.
    """
    plt.plot(loss_history)
    plt.xlabel("Iterations")
    plt.ylabel("Log Marginal Likelihood")
    plt.title("Marginal Log-Likelihood History")
    plt.grid()
    plt.show()

# %% [markdown]
# We set the initial set of values for the optimiser to be $\theta^{(0)} = (1, 1)$ and $\sigma^{(0)} = 0.1$. Note that the CG method (and in general most optimisation algorithms) can be **very sensitive** to the starting point.

# %%
init_params = {'theta1': 1., 'theta2': 1., 'sigma': 0.1}
optimisation_results1 = optim_hyperparams(init_params=init_params, data_X=toy_X, data_y=toy_y, gp=gp_testing, maxiter=1000)

# Dislay the optimized parameters
print('='*100)
print("Max Log-Likelihood: {}".format(optimisation_results1['max_log_likelihood']))
print("Optimized parameters:")
print(optimisation_results1['optimized_params'])
print('='*100)

# Plot
plot_likelihood_history(optimisation_results1['log_likelihood_history'])
# Out:
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-0.9990, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1.1986, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1.3993, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1.6000, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1.7995, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1.9969, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-2.1921, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-2.3867, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-2.5839, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-2.7869, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-2.9978, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-3.2163, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-3.4412, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-3.6705, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-3.9019, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-4.1340, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-4.3672, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-4.6046, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-4.8498, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-5.1044, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-5.3669, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-5.6336, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-5.9007, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-6.1677, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-6.4383, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-6.7157, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-6.9978, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-7.2768, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-7.5440, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-7.7962, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.0343, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.2535, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.4414, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.5858, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.6845, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.7439, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.7699, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.7636, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.7263, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.6667, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.5970, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.5236, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.4471, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.3700, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.2994, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.2393, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.1883, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.1458, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.1153, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.0979, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.0907, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.0931, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.1069, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.1307, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.1618, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.2007, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.2473, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.2987, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.3541, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.4138, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.4753, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.5372, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.5998, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.6608, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.7191, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.7749, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.8261, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.8726, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.9144, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.9501, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-8.9807, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0058, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0254, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0407, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0515, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0590, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0636, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0661, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0673, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0675, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0679, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0685, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0702, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0729, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0773, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0833, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.0911, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1008, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1124, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1256, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1405, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1567, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1742, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.1925, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.2117, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.2312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.2510, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.2707, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.2901, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.3091, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.3274, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.3450, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.3616, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.3773, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.3920, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4057, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4184, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4302, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4411, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4512, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4606, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4695, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4780, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4861, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.4940, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5017, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5095, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5173, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5252, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5333, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5416, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5501, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5589, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5679, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5771, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5865, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.5960, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6054, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6141, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6210, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6251, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6349, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6533, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6609, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6657, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6812, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6887, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.6947, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7082, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7138, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7217, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7328, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7376, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7466, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7553, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7603, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7694, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7765, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7821, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7907, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.7972, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8031, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8112, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8175, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8236, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8378, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8438, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8510, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8579, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8639, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8705, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8775, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8838, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8899, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.8965, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9031, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9092, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9152, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9214, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9277, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9337, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9395, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9452, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9510, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9569, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9627, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9683, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9738, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9792, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9845, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9897, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9948, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-9.9998, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0046, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0091, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0132, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0171, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0214, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0270, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0339, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0405, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0454, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0490, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0526, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0572, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0631, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0692, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0744, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0785, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0822, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0864, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0914, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.0969, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1023, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1070, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1112, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1151, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1190, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1231, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1274, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1320, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1367, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1415, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1460, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1503, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1544, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1584, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1622, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1658, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1690, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1715, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1732, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1744, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1772, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1837, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1917, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1966, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1977, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.1988, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2034, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2100, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2146, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2166, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2187, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2232, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2288, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2330, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2356, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2383, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2423, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2471, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2514, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2546, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2574, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2605, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2644, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2686, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2724, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2757, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2786, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2814, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2844, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2876, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2910, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2945, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.2979, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3011, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3043, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3073, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3103, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3132, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3160, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3186, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3208, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3222, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3223, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3209, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3197, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3236, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3334, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3408, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3407, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3384, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3415, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3492, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3535, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3530, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3539, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3594, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3649, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3667, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3675, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3710, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3762, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3797, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3813, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3833, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3872, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3914, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3942, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3960, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.3982, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4015, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4049, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4077, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4097, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4117, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4141, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4169, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4197, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4222, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4244, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4264, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4284, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4306, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4329, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4353, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4377, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4402, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4426, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4449, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4472, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4495, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4517, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4540, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4562, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4582, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4601, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4615, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4618, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4602, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4556, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4500, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.4517, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# ...
# logabsdet=tensor(-10.9775, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9786, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9798, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9810, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9821, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9831, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9839, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9846, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9848, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9845, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9832, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9805, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9755, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9679, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9587, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9516, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9517, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9596, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9696, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9757, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9758, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9710, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9643, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9596, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9598, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9647, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9712, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9759, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9776, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9770, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9757, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9756, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9777, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9816, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9862, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9900, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9926, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9938, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9941, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9942, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9944, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9951, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9962, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9976, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9990, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0001, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0009, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0011, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0011, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0008, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0004, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9999, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9994, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9989, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9985, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9981, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9978, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9975, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9973, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9972, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9970, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9969, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9968, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9967, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9966, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9965, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9965, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9964, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9963, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9962, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9962, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9963, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9964, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9967, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9971, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9976, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9983, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9991, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9999, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0008, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0018, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0027, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0036, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0044, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0052, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0060, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0067, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0072, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0076, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0078, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0077, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0073, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0064, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0050, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0031, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0010, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9990, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9976, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9975, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-10.9987, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0010, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0036, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0059, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0077, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0088, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-11.0093, grad_fn=<LinalgSlogdetBackward0>))
# ====================================================================================================
# Max Log-Likelihood: 4.005377849249236
# Optimized parameters:
# {'sigma': 4.9687172636664215e-05, 'theta1': 1.0480025528821, 'theta2': 7.3235709067738775}
# ====================================================================================================

# %% [markdown]
# ## Mauga Loa Atmospheric $\textrm{CO}_2$ Data
# ***

# %% [markdown]
# In the second part of this notebook, we will apply our GP model to a real-life dataset concerning the concentration of $\textrm{CO}_2$. The [Mauna Loa Atmospheric $\textrm{CO}_2$ dataset](https://gml.noaa.gov/ccgg/trends/) consists of concentration of $\textrm{CO}_2$  (in parts per million by volume (ppm)) from the Mauna Loa Observatory from 1958 to 2022. We are interesting in modelling this concentration against time and extrapolating it to future years.
#
# The input $x$ is the observation time (`decimal date`) and the observed target $y$ is the monthly average concentration level (`average`). We aim to fit a **noisy** GP regression model, as we expect the targets are corrupted by noises, potentially due to, e.g., observational error or measurement inaccuracies.
#
# <!-- Note that since this is a time-series data, we expect the observed targets to be **correlated** given test inputs. This renders  -->

# %% [markdown]
# ### Loading Data

# %%
# Download data
url = "https://gml.noaa.gov/webdata/ccgg/trends/co2/co2_mm_mlo.csv"
df = pd.read_csv(url, skiprows=40) # skip the first 56 rows containing comments
display(df.head())

# Plot data
df.plot(x="decimal date", y="average")

# Convert data to numpy array
data_X = torch.tensor(df["decimal date"].to_numpy())
data_y = torch.tensor(df["average"].to_numpy())

# Substract empirical mean
data_y -= torch.mean(data_y)
# Out:
#    year  month  decimal date  average  deseasonalized  ndays  sdev   unc
# 0  1958      3     1958.2027   315.70          314.43     -1 -9.99 -0.99
# 1  1958      4     1958.2877   317.45          315.16     -1 -9.99 -0.99
# 2  1958      5     1958.3699   317.51          314.71     -1 -9.99 -0.99
# 3  1958      6     1958.4548   317.24          315.14     -1 -9.99 -0.99
# 4  1958      7     1958.5370   315.86          315.18     -1 -9.99 -0.99

# %% [markdown]
# ## Specifying Kernel Function
# ***

# %% [markdown]
# We choose as the kernel function a sum of 4 kernel functions that are able to capture different characteristics of the data (recall that sums and products of kernel functions are also kernel functions). Note that we are not claiming this is the best kernel function -- it is entirely possible that other choices are more appropriate for this problem.
#
# 1. To model the long-term smooth trend, we use a RBF kernel
#
#
# $$
# k_1(x, x') = \theta_1^2 \exp\left( - \frac{\| x - x' \|_2^2}{2\theta_2^2} \right) \;.
# $$
#
#
# 2. To model the periodic behaviour, we use a product of a RBF kernel and a **periodic kernel**, taking the form
#
#
# $$
# k_2(x, x') = \theta_3^2 \exp\left( - \frac{\| x - x' \|_2^2}{2 \theta_4^2} - \frac{2 \sum_{k=1}^d\sin^2( \pi (x_k - x_k') )}{\theta_5^2} \right) \;,
# $$
#
#
# where $\theta_3$ represents the magnitude, $\theta_4$ is the **decay-time** for the periodic component, and $\theta_5$ gives its smoothness. The period (in the argument of $\sin$) has been set to one (year). This is because the seasonal effect is believed to be caused primarily by the different $\textrm{CO}_2$ level uptake for plants depending on the season, although in principle we could have introduced another hyper-parameter to model it completely from the data. **The sum is taken over the dimensions**
#
# 3. To model the small/medium-term irregularities, we use a **rational quadratic kernel**
#
#
# $$
# k_3(x, x') = \theta_6^2 \left( 1 + \frac{\| x - x' \|_2^2}{2 \theta_7^2 \theta_8} \right)^{- \theta_8} \;,
# $$
#
#
# where $\theta_6$ gives the magnitude, $\theta_7$ the standard length-scale, and $\theta_8$ the shape parameter. One could have used a RBF kernel for this component. However, since we are interested in modelling the **small/medium** effect, a rational quadratic kernel is a better choice. This is because this kernel decays **polynomially** as a function of $\| x - x'\|_2^2$ (controlled by $\theta_8$), whereas the decay in RBF is exponentially and therefore much faster. This means a rational quadratic kernel can accommodate several length-scales better than a RBF can do.
#
# 4. To model the noise term, we use a sum of correlated and uncorrelated components
#
#
# $$
# k_4(x_p, x_q) = \theta_9^2 \exp\left( - \frac{\| x_p - x_q \|_2^2}{2\theta_{10}^2} \right) + \theta_{11}^2 \delta_{pq} \;,
# $$
#
#
# where $\theta_9$ is the magnitude of the correlated component, $\theta_{10}$ the length-scale, and $\theta_{11}$ the magnitude of the uncorrelated component. The correlated term is introduced because the data is a time-series that is believed to suffer from systematic noises (measurement inaccuracies, short-term weather phenomenon etc.). The uncorrelated term serves **exactly the same role as the noise term $\sigma^2 \delta_{pq}$ in a noisy GP model** except a renaming.
#
# **Therefore, when instantiating $k_4$ in our code we could equivalently only create a RBF kernel with parameters $\theta_9$ and $\theta_{10}$, and the $\theta_{11}$ will be taken over by the `sigma` in `gp.predict`**.
#
# One may also wonder whether the first component in $k_4$ is redundant as it has an identical form as $k_1$. The answer is no -- we will see that after hyper-parameter optimisation one will have a **short length-scale (noise)** and the other a **long length-scale (the long-term signal)**. These two terms are, however, **unidentifiable**, meaning that we may observe $k_1$ to have a long length-scale and the first term in $k_4$ to have a short length-scale, and vice versa. It is only a matter of interpretation that we have chosen to call one the "noise" term and the other the "signal".
#
# These choices are made based on our prior understanding of the data (e.g., by inspecting the data plot). This is often how the kernel function for GPs are consructed in practice, where the practitioner choose a combination of kernels that can model different characteristics of the data. For example, the periodic kernel is used if the data exhibit periodic trend, and the RBF kernel is often the go-to choice to model smooth functions. A survey of well-known kernel functions can be found on this [kernel cookbook](https://www.cs.toronto.edu/~duvenaud/cookbook/).

# %% [markdown]
# #### Exercise 6
# Complete the code below to implement the Periodic kernel and the Rational Quadratic kernel and the 'Sum' Kernel.

# %%
class Periodic(Kernel):

    def __init__(self, params: dict):
        self.theta3 = params['theta3']
        self.theta4 = params['theta4']
        self.theta5 = params['theta5']

    def set_params(self, params: dict):
        self.theta3 = params['theta3']
        self.theta4 = params['theta4']
        self.theta5 = params['theta5']

    def __call__(self, x1, x2):
        """
        Compute the periodic kernel matrix.
diff = x1.unsqueeze(1) - x2.unsqueeze(0)  # Broadcasting to get pairwise differences
        squared_diff_matrix = (diff ** 2).sum(dim=-1)
        Args:
        x1 (torch.Tensor): Input tensor of shape (n, d).
        x2 (torch.Tensor): Input tensor of shape (m, d).

        Returns:
        torch.Tensor: Kernel matrix of shape (n, m).
        """
        x1, x2 = self.check_shapes(x1, x2)
        diff = x1.unsqueeze(1) - x2.unsqueeze(0)  # Broadcasting to get pairwise differences
        squared_diff_matrix = (diff ** 2).sum(dim=-1)
        
        sin_mat = torch.sin(torch.pi * diff) ** 2
        k_mat =  self.theta3**2 * torch.exp(-squared_diff_matrix/(2*self.theta4**2) 
                                             - 2/(self.theta5 **2) * torch.sum(sin_mat,dim = -1))
        
        
        return k_mat

# %%
class RationalQuadratic(Kernel):

    def __init__(self, params: dict):
        self.theta6 = params['theta6']
        self.theta7 = params['theta7']
        self.theta8 = params['theta8']
    
    def set_params(self, params: dict):
        self.theta6 = params['theta6']
        self.theta7 = params['theta7']
        self.theta8 = params['theta8']

    def __call__(self, x1, x2):
        """
        Compute the rational quadratic kernel matrix.

        Args:
        x1 (torch.Tensor): Input tensor of shape (n, d).
        x2 (torch.Tensor): Input tensor of shape (m, d).

        Returns:
        torch.Tensor: Kernel matrix of shape (n, m).
        """
        x1, x2 = self.check_shapes(x1, x2)

        ###### TODO ######
        diff = x1.unsqueeze(1) - x2.unsqueeze(0)  # Broadcasting to get pairwise differences
        squared_diff_matrix = (diff ** 2).sum(dim=-1)
        k_mat = self.theta6**2 * (1 + squared_diff_matrix/(2*self.theta7 **2 * self.theta8))**(-self.theta8)
        return k_mat

# %%
class Sum(Kernel):
    
    def __init__(self, params: dict):

        rbf_params = {p: params[p] for p in ['theta1', 'theta2']}
        periodic_params = {p: params[p] for p in ['theta3', 'theta4', 'theta5']}
        rq_params = {p: params[p] for p in ['theta6', 'theta7', 'theta8']}
        rbf2_params = {key: params[p] for key, p in zip(['theta1', 'theta2'],['theta9', 'theta10'])}

        self.rbf = RBF(rbf_params)
        self.rbf2 = RBF(rbf2_params)
        self.periodic = Periodic(periodic_params)
        self.rq = RationalQuadratic(rq_params)

    def set_params(self, params: dict):
            
        rbf_params = {p: params[p] for p in ['theta1', 'theta2']}
        periodic_params = {p: params[p] for p in ['theta3', 'theta4', 'theta5']}
        rq_params = {p: params[p] for p in ['theta6', 'theta7', 'theta8']}
        rbf2_params = {key: params[p] for key, p in zip(['theta1', 'theta2'],['theta9', 'theta10'])}

        self.rbf.set_params(rbf_params)
        self.rbf2.set_params(rbf2_params)
        self.periodic.set_params(periodic_params)
        self.rq.set_params(rq_params)

    def __call__(self, x1, x2):
        """
        Compute the sum kernel matrix k = k_rbf + k_periodic + k_rq + k_rbf2.

        Args:
        x1 (torch.Tensor): Input tensor of shape (n, d).
        x2 (torch.Tensor): Input tensor of shape (m, d).

        Returns:
        torch.Tensor: Kernel matrix of shape (n, m).
        """

        ###### TODO ######
        k_rbf = self.rbf(x1,x2)
        k_periodic = self.periodic(x1,x2)
        k_rq = self.rq(x1,x2)
        k_rbf2 = self.rbf2(x1,x2)

        k_mat = k_rbf+k_periodic+k_rq+k_rbf2
        
        return k_mat

# %%
# To test here we are going to use a 2d dataset
toy_X_2d = toy_X.unsqueeze(1).repeat(1, 2)

ker_periodic_testing = Periodic({'theta3': 1., 'theta4': 1., 'theta5': 1.})
ker_rq_testing = RationalQuadratic({'theta6': 1., 'theta7': 1., 'theta8': 1.})
ker_sum_testing = Sum({'theta{}'.format(i): 1. for i in range(1, 11)})

# Testing kernels
print('-'*50)
print('Testing Periodic Kernel')
print(ker_periodic_testing(toy_X_2d, toy_X_2d).shape)
print(ker_periodic_testing(toy_X_2d, toy_X_2d))
print('-'*50)
print('Testing Rational Quadratic Kernel')
print(ker_rq_testing(toy_X_2d, toy_X_2d).shape)
print(ker_rq_testing(toy_X_2d, toy_X_2d))
print('-'*50)
print('Testing Sum Kernel')
print(ker_sum_testing(toy_X_2d, toy_X_2d).shape)
print(ker_sum_testing(toy_X_2d, toy_X_2d))
print('-'*50)
# Out:
# --------------------------------------------------
# Testing Periodic Kernel
# torch.Size([3, 3])
# tensor([[1.0000, 0.3679, 0.0183],
#         [0.3679, 1.0000, 0.3679],
#         [0.0183, 0.3679, 1.0000]])
# --------------------------------------------------
# Testing Rational Quadratic Kernel
# torch.Size([3, 3])
# tensor([[1.0000, 0.5000, 0.2000],
#         [0.5000, 1.0000, 0.5000],
#         [0.2000, 0.5000, 1.0000]])
# --------------------------------------------------
# Testing Sum Kernel
# torch.Size([3, 3])
# tensor([[4.0000, 1.6036, 0.2549],
#         [1.6036, 4.0000, 1.6036],
#         [0.2549, 1.6036, 4.0000]])
# --------------------------------------------------

# %% [markdown]
# Expected output:
# ```python
# --------------------------------------------------
# Testing Periodic Kernel
# torch.Size([3, 3])
# tensor([[1.0000, 0.3679, 0.0183],
#         [0.3679, 1.0000, 0.3679],
#         [0.0183, 0.3679, 1.0000]])
# --------------------------------------------------
# Testing Rational Quadratic Kernel
# torch.Size([3, 3])
# tensor([[1.0000, 0.5000, 0.2000],
#         [0.5000, 1.0000, 0.5000],
#         [0.2000, 0.5000, 1.0000]])
# --------------------------------------------------
# Testing Sum Kernel
# torch.Size([3, 3])
# tensor([[4.0000, 1.6036, 0.2549],
#         [1.6036, 4.0000, 1.6036],
#         [0.2549, 1.6036, 4.0000]])
# --------------------------------------------------

# %% [markdown]
# ## Fitting the Model
# ***

# %% [markdown]
# Let us fit a GP regression model with a set of arbitrarily chosen kernel hyper-parameters.

# %%
sample_params = {'theta{}'.format(i): 0.5 for i in range(1, 11)}

sum_kernel = Sum(sample_params)
gp = GP(kernel=sum_kernel)

# predict 20 years into the future
pred_X = torch.arange(data_X.max().item() + 1/12., 2043., step=1/12.)
pred_y = gp.predict(pred_X, data_X, data_y, size=100, sigma=0.01)

# %%
def plot_predicted_co2(data_X, data_y, pred_X, pred_y):
    """
    Plotting util for CO2 predictions.
    """
    fig = plt.figure()
    plt.plot(data_X.numpy(), data_y.numpy(), color='blue', label="observed")
    plt.plot(pred_X.numpy(), np.transpose(pred_y.numpy()), label="predicted", color="cyan", alpha=0.2)
    plt.xlabel("Year")
    plt.ylabel("Predicted concentration (centred)")
    plt.grid()
    plt.show()

# %%
# Posterior predictions with non optimal params
plot_predicted_co2(data_X, data_y, pred_X, pred_y)

# %% [markdown]
# Let us now optimise the kernel hyper-parameters to improve the model fitting.
#
# The final hyper-parameter values above are only a **local** optima, since the objective function is highly likely to be **multi-modal** (it is defined on a 11-dimensional space!). One way to accommodate this is to **try multiple starting points** for the optimisation algorithm, and select the one that gives the highest log marginal likelihood.
#
# We use 10 sets of initial values, and find the best hyper-parameters in the 10 runs. We could randomly generate these values from some given intervals, as usually done in practice. However, this will take an long time. For the sake of this tutorial, we generate initial values **close to a set of local optima** reported in Rasmussen CE. Gaussian processes in machine learning. InSummer school on machine learning 2003 Feb 2 (pp. 63-71). Springer, Berlin, Heidelberg..

# %%
def optim_hyperparams_multiple_runs(init_params_list, data_X, data_y, gp, maxiter=60, learning_rate=0.02):
    """
    Perform hyperparameter optimization for a Gaussian Process model multiple times, each with 
    different initial hyperparameters. This function is useful for exploring the hyperparameter 
    space more thoroughly and finding a set of hyperparameters that maximizes the log marginal likelihood.

    Args:
    init_params_list (list of dicts): A list of dictionaries, each containing a set of initial 
                                      hyperparameters for the optimization process.
    data_X (torch.Tensor): Training data features as a torch.Tensor.
    data_y (torch.Tensor): Training data targets as a torch.Tensor.
    gp (GP): An instance of the Gaussian Process model.
    maxiter (int, optional): The number of iterations for each optimization run. Default is 60.
    learning_rate (float, optional): Learning rate for the optimizer. Default is 0.02.

    Returns:
    dict: A dictionary containing:
          - 'optim_res_list': A list of dictionaries, each representing the optimized hyperparameters 
                              from each run.
          - 'log_likelihood_history_list': A torch.Tensor containing the log likelihood history for each run.
          - 'max_log_likelihood_list': A list of the maximum log likelihood values achieved in each run.
          - 'params_history_list': A list of dictionaries, each mapping hyperparameters to their values 
                                   over iterations for each run.
    
    The function prints progress updates and indicates when all runs are completed.
    """
    
    optim_res_list = []
    log_lik_history_list = []
    max_log_likelihood_list = []
    params_history_list = []

    nrep = len(init_params_list)

    for i in range(nrep):
        
        print(f"iter {i + 1} out of {nrep}")
        init_params = init_params_list[i]

        # Find best parameters using the PyTorch-based optimizer
        results = optim_hyperparams(gp, init_params, data_X, data_y, maxiter=maxiter, learning_rate=learning_rate)

        max_log_likelihood_list.append(results['max_log_likelihood'])
        log_lik_history_list.append(torch.tensor(results['log_likelihood_history']))
        optim_res_list.append(results['optimized_params'])
        params_history_list.append(results['params_history'])

    
    log_lik_history_list = torch.stack(log_lik_history_list)
    print('Done!')
        

    return {'optim_res_list': optim_res_list, 'log_likelihood_history_list': log_lik_history_list, 
            'max_log_likelihood_list': max_log_likelihood_list, 'params_history_list': params_history_list}

# %%
# Initailise list of parameters
number_of_initial_lists = 10

normal_noise = torch.randn(size=(number_of_initial_lists, 11)) * torch.tensor(
    [1., 1., 0.5, 1., 0.5, 0.1, 0.5, 0.1, 0.1, 0.5, 0.1])

init_params_list = torch.tensor([66., 67., 2.4, 90., 1.3, 0.66, 1.2, 0.78, 0.18, 1.6, 0.19]) + normal_noise

# Convert to list of dictionaries
initial_params_list = []
for i in range(number_of_initial_lists):
    sample_params_dict = {'theta{}'.format(i+1): z.item() for i, z in enumerate(init_params_list[i,:-1])}
    sample_params_dict['sigma'] = init_params_list[i,-1].item()
    initial_params_list.append(sample_params_dict)

# Printing initial_params_list first two elements to see how they look like
print(initial_params_list[0])
print('='*100)
print(initial_params_list[1])

#res = optim_hyperparams_multiple_runs(list1, data_X, data_y, gp, maxiter=1000)
# Out:
# {'theta1': 67.46378080452699, 'theta2': 64.13892786678737, 'theta3': 1.9939633192958022, 'theta4': 90.52958362446284, 'theta5': 1.2848560434673824, 'theta6': 0.5907418083863581, 'theta7': 1.4703025759997452, 'theta8': 0.7388092382948022, 'theta9': 0.2606521769825496, 'theta10': 1.9152598985785048, 'sigma': 0.20421454188283542}
# ====================================================================================================
# {'theta1': 66.86559541970263, 'theta2': 66.56020929702417, 'theta3': 2.557261967362755, 'theta4': 91.01828431443704, 'theta5': 1.6913239260278612, 'theta6': 0.707811994999388, 'theta7': 1.0293166747940568, 'theta8': 0.9298223105574094, 'theta9': 0.214378042788438, 'theta10': 2.8028182423418286, 'sigma': 0.12698977493972474}

# %%
# Run hyper-parameter search with multiple starting points
# Here we are giving as input thegp initialized a couple of cells above
# Takes approx 4 to 5 mins to run
res = optim_hyperparams_multiple_runs(initial_params_list, data_X, data_y, gp, maxiter=500, learning_rate=0.04)
# Out:
# iter 1 out of 10
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-2156.9470, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1888.0154, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1698.4358, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1575.3391, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1503.1112, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1468.9613, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1463.7138, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1481.0536, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1516.6071, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1567.0438, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1629.2307, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1699.3259, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1771.6949, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1837.9221, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1887.2952, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1910.7225, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1906.3194, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1880.9051, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1847.5740, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1828.5747, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1806.6911, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1763.5799, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1734.2712, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1720.4154, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1719.3117, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1728.4623, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1745.4796, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1768.0517, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1794.5586, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.2880, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1875.0646, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1915.3796, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1858.8357, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3790, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1800.8354, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1778.9302, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1762.6691, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1755.5605, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1761.7020, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1786.8367, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1836.7411, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1840.3818, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1813.8939, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1803.2358, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1803.4110, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1808.8554, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1816.7635, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5075, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1838.7280, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1851.4513, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1850.6405, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1828.5952, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1804.9752, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1790.6445, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1787.3396, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1794.0904, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1808.8072, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1828.2688, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1846.9692, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1855.8813, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1849.2682, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1833.4988, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1817.6215, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1806.8131, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1803.4080, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1807.7946, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1818.1269, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1829.4235, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1834.7190, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1831.8032, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.3663, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1820.2246, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1818.5178, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1820.5272, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.2074, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1829.9914, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1831.2050, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1827.0869, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1820.3275, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1815.2227, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1814.2903, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1817.7286, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9300, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1830.0181, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1832.8464, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1830.9621, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.8528, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1820.5539, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1817.5362, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1817.7898, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1820.7445, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.5652, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1827.0300, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.9940, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.1389, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.0917, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1822.1521, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1822.7174, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.2474, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.5559, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.5384, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0852, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1822.2244, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1821.2530, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1821.8312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6659, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.7031, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.7123, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.0958, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.3368, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1822.5920, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1821.8555, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1822.3947, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6832, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.7828, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1825.0134, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.4355, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6882, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.4005, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.7396, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.3463, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.6336, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.2789, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.5207, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1822.9508, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.0167, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6878, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.4902, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.8608, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.5787, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9211, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.3984, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.3424, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6880, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0754, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.1756, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9701, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.7271, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.7202, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9764, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.2627, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.3016, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0329, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6737, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.5182, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.6791, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0035, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.2198, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.1809, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9785, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8269, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8501, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9806, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0490, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9674, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8194, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.7660, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8753, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0531, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.1372, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0576, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9002, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8113, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8515, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9500, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9931, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9480, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8876, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8966, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9732, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0324, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1824.0043, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9129, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8490, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8703, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9439, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9894, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9704, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9271, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9193, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9534, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9796, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9576, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9078, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.8862, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9167, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9641, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9780, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9517, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9240, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9271, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9482, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9519, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9293, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9094, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9193, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9487, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9631, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9485, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9265, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9235, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9368, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9427, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9315, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9204, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9272, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9448, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9509, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9390, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9257, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9268, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9361, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9377, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9297, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9262, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9342, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9433, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9410, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9310, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9268, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9318, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9360, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9327, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9284, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9313, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9379, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9382, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9320, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9282, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9309, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9340, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9321, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9291, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9310, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9353, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9352, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9311, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9292, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9314, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9328, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9309, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9295, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9317, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9341, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9329, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9303, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9303, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9320, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9317, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9301, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9304, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9325, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9328, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9305, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9315, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9318, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9306, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9303, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9317, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9323, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9314, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9309, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9316, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9318, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9309, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9307, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9316, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9320, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9314, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9313, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9319, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9319, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9319, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9320, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9316, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9319, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9323, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9321, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9318, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9320, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9324, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9322, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9322, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9326, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9328, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9325, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9326, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9329, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9328, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9328, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9331, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9333, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9333, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9333, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9336, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9336, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9336, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9338, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9340, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9340, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9342, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9344, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9345, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9345, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9347, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9349, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9350, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9352, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9354, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9355, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9356, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9358, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9360, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9361, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9363, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1823.9365, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# ...
# logabsdet=tensor(-1826.5259, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5299, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5296, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5263, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5228, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5218, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5241, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5284, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5321, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5331, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5312, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5278, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5249, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5240, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5250, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5264, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5266, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5248, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5216, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5185, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5168, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5169, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5181, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5190, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5186, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5170, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5150, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5135, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5131, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5134, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5134, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5125, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5104, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5078, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5054, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5038, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5028, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5018, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.5002, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4977, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4949, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4923, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4902, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4884, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4867, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4844, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4816, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4785, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4755, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4730, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4708, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4686, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4661, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4632, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4602, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4574, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4549, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4525, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4501, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4473, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4442, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4411, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4381, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4353, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4325, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4296, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4264, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4231, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4198, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4167, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4136, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4105, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4073, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4039, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.4005, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3971, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3938, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3905, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3872, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3837, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3802, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3766, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3732, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3698, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3664, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3629, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3593, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3557, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3521, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3486, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3451, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3415, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3378, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3341, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3304, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3268, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3231, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3194, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3157, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3119, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3082, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3045, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.3007, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.2970, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.2932, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.2894, grad_fn=<LinalgSlogdetBackward0>))
# torch.return_types.linalg_slogdet(
# sign=tensor(1., grad_fn=<LinalgSlogdetBackward0>),
# logabsdet=tensor(-1826.2856, grad_fn=<LinalgSlogdetBackward0>))
# Done!

# %%
# Plot the log likelihood history for each run (we plot from iteration 1 onwards)
plt.figure(figsize=(8, 6))
plt.plot(res['log_likelihood_history_list'][:,1:].detach().numpy().T)
plt.grid()
plt.xlabel("Iterations")
plt.ylabel("Negative Log Marginal Likelihood")
plt.title("Marginal Log-Likelihood History")
plt.show()

# %% [markdown]
# #### Exercise 7 - python skills

# %%
###### TODO ######
# Extracting the index of the max of maximum log likelihood list and the maximum log likelihood
max_log_likelihood_idx = np.argmax(res["max_log_likelihood_list"])
max_log_likelihood = res["max_log_likelihood_list"][max_log_likelihood_idx]
print('Index of the maximum log likelihood: {}'.format(max_log_likelihood_idx))
print('Maximum log likelihood: {}'.format(max_log_likelihood))
print('-'*100)

###### TODO ######
# Extracting the best optimized parameters

optimized_params = res["optim_res_list"][max_log_likelihood_idx]
#print('Optimized parameters: {}'.format(optimized_params))

# Computing the predicted values
sum_kernel.set_params(optimized_params)
gp.k = sum_kernel
pred_y = gp.predict(pred_X, data_X, data_y, size=100, sigma=optimized_params['sigma'])
# Out:
# Index of the maximum log likelihood: 6
# Maximum log likelihood: 518.78419502266
# ----------------------------------------------------------------------------------------------------

# %%
plot_predicted_co2(data_X, data_y, pred_X, pred_y)

# %% [markdown]
# **Optional:** In the cell below I want you to plot a figure of subplots (2 rows and 5 columns) where in each plot I can see the evolution of the parameters for each initial values. I.e. in the firt plot I should see `number_of_initial_lists` lines reresenting the update of theta1 in the optimisation loop.

# %%
# Create a subplot with 2 rows and 5 columns
fig, axes = plt.subplots(2, 5, figsize=(15, 8))

# Flatten the axes array
axes = axes.flatten()

# Iterate over the parameters
for i in range(number_of_initial_lists):
    # Get the parameter name
    param_name = 'theta{}'.format(i+1)
    
    # Get the parameter history for each run
    param_history = torch.cat([params[param_name].unsqueeze(0) for params in res['params_history_list']], dim=0)
    
    # Plot the parameter history
    axes[i].plot(param_history.numpy().T)
    axes[i].set_title(param_name)
    axes[i].set_xlabel('Iteration')
    axes[i].set_ylabel('Parameter Value')
    axes[i].grid()

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Interpretation of Kernel Hyper-Parameters
# ***

# %% [markdown]
# Taking the final parameters
# ```python
# final_params = [15.60917401 37.85666397 51.65420898 41.91108205  6.60621616  0.45302811
#   0.54545549 21.92928839 27.86849259 20.36595657 -0.25296079]
#
# ```
# as an example, we see that:
#
# - The long-term trend has magnitude $\theta_1 \approx 16$ and a length-scale of $\theta_2 \approx 38$ years.
#
# - The periodic contribution has magnitude $\theta_3 \approx 52$, decay-time $\theta_4 \approx 42$ years, and smoothness $\theta_5 \approx 7$. The long decay-time shows that the data has a component that is very close to a seasonal periodicity in the short term.
#
# - The medium/short-term component has magnitude $\theta_6 \approx 0.5$ ppm, length-scale $\theta_7 \approx 0.5$ yearms and shape $\theta_8 \approx 22$.
#
# - The correlated noise term has amplitude $\theta_9 \approx 28$ and lengt-scale $\theta_{10} \approx 20$, and the uncorrelated noise term has magnitude $\theta_{11} \approx 0.3$ (we take the absolute value due to unidentifiability: $\theta_{11}^2 = (-\theta_{11})^2$). The relatively small value of $\theta_{11}$ suggests the uncorrelated noise level is small compared with the signal in the data, and the data have been very well explained by the model.
#
# As mentioned previously, this is only a local optimum and thus only one of many plausible sets of hyper-parameters that can explain the data. Each local optimum will correspond to a different interpretation of these parameters. You are encouraged to play around with the starting points and plot the resulting posterior draws to see how different hyper-parameters can affect the predictions.

# %% [markdown]
# ***
